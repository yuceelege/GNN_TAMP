# %%
import time
import random
import os

# %%
import random
from itertools import combinations, chain

def generate_instance():
    num_objects = random.randint(2,6)
    objects = list(range(1, num_objects + 1))

    all_groupings = list(chain(*[combinations(objects, i) for i in range(1, num_objects + 1)]))

    sampled_groupings = []
    while objects:
        group = random.choice(all_groupings)
        sampled_groupings.append(group)
        for obj in group:
            objects.remove(obj)
            all_groupings = [g for g in all_groupings if obj not in g]
    
    return sampled_groupings

def random_uniform_rounded(low, high, decimal_places=2):
    return round(random.uniform(low, high), decimal_places)
def random_offset():
    if random.choice([True, False]):
        return random_uniform_rounded(1, 1.5)
    else:
        return random_uniform_rounded(-1.5, -1)

def generate_unique_numbers(n, start,end):
    unique_numbers = set()
    while len(unique_numbers) < n:
        number = random.uniform(start,end)
        if all(abs(number-existing_number) >= 0.2 for existing_number in unique_numbers):
            unique_numbers.add(number)
    return list(unique_numbers)

def generate_random_rgb():
    return (random_uniform_rounded(0, 1) for _ in range(3))

# %%
no_pattern1 = 1000
for i in range(0,1000):
    file_name = f"data_gfile3_ceren/sample_{i+20001}.g"
    x_offsets = random.uniform(3,-3)
    y_offsets = random.uniform(3,-3)
    with open(file_name, "w") as file:
        line = f'object{1}: {{ X: [{x_offsets}, {y_offsets}, {0}, 0.3, 0, 0, 0], shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}'
        file.write(line + "\n")
        line = f'object{2}: {{ X: [{x_offsets+random.uniform(0.5,0)+cube_size}, {y_offsets}, {0}, 0.3, 0, 0, 0], shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}'
        file.write(line + "\n")
        line = f'object{3}: {{ X: [{x_offsets+random.uniform(0.5,0)+cube_size}, {y_offsets}, {0}, 0.3, 0, 0, 0], shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}'
        file.write(line + "\n")
        line = (f'object{4}(object{1}): {{ Q: "t({cube_size/2} {0} {cube_size+random.uniform(0.5,0)}) d({0} 0 0 1)",'
                f'shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}')
        file.write(line + "\n")
        line = (f'object{5}(object{2}): {{ Q: "t({cube_size/2} {0} {cube_size+random.uniform(0.5,0)}) d({0} 0 0 1)",'
                f'shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}')
        file.write(line + "\n")
        line = (f'object{6}(object{4}): {{ Q: "t({cube_size/2} {0} {cube_size+random.uniform(0.5,0)}) d({0} 0 0 1)",'
                f'shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}')
        file.write(line + "\n")

# %%
no_pattern2 = 1000
for i in range(0,1000):
    file_name = f"data_gfile3_ceren/sample_{i+21001}.g"
    x_offsets = random.uniform(3,-3)
    y_offsets = random.uniform(3,-3)
    with open(file_name, "w") as file:
        line = f'object{1}: {{ X: [{x_offsets}, {y_offsets}, {0}, 0.3, 0, 0, 0], shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}'
        file.write(line + "\n")
        line = f'object{2}: {{ X: [{x_offsets+random.uniform(0.5,0)+cube_size}, {y_offsets}, {0}, 0.3, 0, 0, 0], shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}'
        file.write(line + "\n")
        line = (f'object{3}(object{1}): {{ Q: "t({-cube_size/2} {0} {cube_size+random.uniform(0.5,0)}) d({0} 0 0 1)",'
                f'shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}')
        file.write(line + "\n")
        line = (f'object{4}(object{2}): {{ Q: "t({-cube_size/2} {0} {cube_size+random.uniform(0.5,0)}) d({0} 0 0 1)",'
                f'shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}')
        file.write(line + "\n")

# %%
no_pattern3 = 1000
for i in range(0,1000):
    file_name = f"data_gfile3_ceren/sample_{i+22001}.g"
    x_offsets = random.uniform(3,-3)
    y_offsets = random.uniform(3,-3)
    with open(file_name, "w") as file:
        line = f'object{1}: {{ X: [{x_offsets}, {y_offsets}, {0}, 0.3, 0, 0, 0], shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}'
        file.write(line + "\n")
        line = f'object{2}: {{ X: [{x_offsets+random.uniform(0.5,0)+cube_size}, {y_offsets}, {0}, 0.3, 0, 0, 0], shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}'
        file.write(line + "\n")
        line = (f'object{3}(object{1}): {{ Q: "t({cube_size/2} {0} {cube_size+random.uniform(0.5,0)}) d({0} 0 0 1)",'
                f'shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}')
        file.write(line + "\n")
        line = (f'object{4}(object{2}): {{ Q: "t({cube_size/2} {0} {cube_size+random.uniform(0.5,0)}) d({0} 0 0 1)",'
                f'shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}')
        file.write(line + "\n")
        line = (f'object{5}(object{3}): {{ Q: "t({cube_size/2} {0} {cube_size+random.uniform(0.5,0)}) d({0} 0 0 1)",'
                f'shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}')
        file.write(line + "\n")

# %%
no_pattern4 = 1000
for i in range(0,1000):
    file_name = f"data_gfile3_ceren/sample_{i+23001}.g"
    x_offsets = random.uniform(3,-3)
    y_offsets = random.uniform(3,-3)
    with open(file_name, "w") as file:
        line = f'object{1}: {{ X: [{x_offsets}, {y_offsets}, {0}, 0.3, 0, 0, 0], shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}'
        file.write(line + "\n")
        line = f'object{2}: {{ X: [{x_offsets+random.uniform(0.5,0)+cube_size}, {y_offsets}, {0}, 0.3, 0, 0, 0], shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}'
        file.write(line + "\n")
        line = (f'object{3}(object{1}): {{ Q: "t({cube_size/2} {0} {cube_size+random.uniform(0.5,0)}) d({0} 0 0 1)",'
                f'shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}')
        file.write(line + "\n")
        line = (f'object{4}(object{3}): {{ Q: "t({cube_size/2} {0} {cube_size+random.uniform(0.5,0)}) d({0} 0 0 1)",'
                f'shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}')
        file.write(line + "\n")

# %%
num_files = 20000
cube_size = 0.8

for i in range(1, num_files+1):
    instances = generate_instance()
    if i == 1:
        print(instances)
    file_name = f"data_gfile3_ceren/sample_{i}.g"
    x_offsets = generate_unique_numbers(len(instances),3 ,-3)
    y_offsets = generate_unique_numbers(len(instances),3 ,-3)
    with open(file_name, "w") as file:
        for i,instance in enumerate(instances):
            k = len(instance) 
            x_pos = x_offsets[i]
            y_pos = y_offsets[i]
            line = f'object{instance[0]}: {{ X: [{x_pos}, {y_pos}, {cube_size/2}, 0.3, 0, 0, 0], shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}'
            file.write(line + "\n")
            if i == 1:
                print(instance)
            for j in range(1, k):
                angle_random = random.randint(0, 180)
                r_random, g_random, b_random = generate_random_rgb()
                line = (f'object{instance[j]}(object{instance[j-1]}): {{ Q: "t({random.uniform(0,0.1)} {random.uniform(0,0.1)} {cube_size}) d({angle_random} 0 0 1)",'
                         f'shape: ssBox, size: [{cube_size}, {cube_size}, {cube_size}, .01], color: [{0.5}, {0.5}, {0.5}]}}')
                file.write(line + "\n")
# Out:
# [(3, 4), (2, 5), (1,)]
# (2, 5)
# (1,)
# (3,)
# (2, 3)
# (3, 4, 5)
# (2, 3)
# (3, 5)
# (1, 2)
# (4,)
# (6,)
# (1,)
# (3,)
# (1,)
# (2, 4)
# (2, 3)
# (2,)
# (1,)
# (1, 2, 4)
# (1,)
# (2,)
# (1,)
# (3,)
# (4,)
# (2,)
# (2,)
# (1, 3)
# (2,)
# (2, 6)
# (2,)
# (5,)
# (5,)
# (3,)
# (5,)
# (3,)
# (3,)
# (1, 3)
# (4,)
# (3,)
# (2,)
# (1,)
# (4,)
# (3,)
# (1, 3)
# (3,)
# (3, 4)
# (2,)
# (1,)
# (1,)
# (1, 2)
# (4,)
# (1,)
# (3, 5, 6)
# (1,)
# (1, 2)
# (1, 4)
# (2, 3)
# (5,)
# (1,)
# (2, 4, 6)
# (3, 5)
# (4, 5)
# (3,)
# (3, 4)
# (3, 4)
# (2,)
# (1,)
# (1,)
# (1,)
# (2, 4)
# (4,)
# (3,)
# (5,)
# (1,)
# (3,)
# (4, 5)
# (1, 3, 4)
# (2,)
# (3,)
# (4,)
# (4,)
# (2,)
# (1,)
# (3,)
# (1,)
# (2, 3)
# (1,)
# (3,)
# (1, 5)
# (4,)
# (3,)
# (1,)
# (2, 4)
# (2, 3, 5, 6)
# (2, 3, 4)
# (4,)
# (3,)
# (5,)
# (2,)
# (1, 5)
# (1, 3, 4)
# (1,)
# (2, 3)
# (4,)
# (4,)
# (4,)
# (1,)
# (6,)
# (3,)
# (3, 4)
# (2,)
# (6,)
# (5,)
# (5, 6)
# (2,)
# (5,)
# (1,)
# (3,)
# (2, 3)
# (1,)
# (1,)
# (4, 5)
# (3,)
# (4,)
# (1,)
# ...
